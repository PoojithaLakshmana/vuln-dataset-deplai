# %%
import pandas as pd

# Load the full record dataset
df = pd.read_json('data/vuln_dataset.jsonl', lines=True)

# Show the first 5 rows nicely
from IPython.display import display
print("📊 Vulnerability Dataset Preview:")
display(df.head())

# Show a few examples of the Training Pairs (Instruction/Response)
print("\n🧠 Training Pairs (What the model learns):")
pairs_df = pd.read_json('data/training_pairs.jsonl', lines=True)
display(pairs_df[['instruction', 'output']].head())
# Out:
# 📊 Vulnerability Dataset Preview:
#               id vulnerability_name         cve_id cwe_id owasp_category  \
# 0  VULN_2E2BD14C      CVE-1999-0095  CVE-1999-0095               Unknown
# 1  VULN_D717FAC1      CVE-1999-1471  CVE-1999-1471               Unknown
# 2  VULN_F8F001B7      CVE-1999-1122  CVE-1999-1122               Unknown
# 3  VULN_2AB3C832      CVE-1999-1467  CVE-1999-1467               Unknown
# 4  VULN_26CDAAE6      CVE-1999-1506  CVE-1999-1506               Unknown
#
#                                          description  \
# 0  The debug command in Sendmail is enabled, allo...
# 1  Buffer overflow in passwd in BSD based operati...
# 2  Vulnerability in restore in SunOS 4.0.3 and ea...
# 3  Vulnerability in rcp on SunOS 4.0.x allows rem...
# 4  Vulnerability in SMI Sendmail 4.0 and earlier,...
#
#                          root_cause            attack_method payload_example  \
# 0  Security control review required  Manual testing required
# ...
